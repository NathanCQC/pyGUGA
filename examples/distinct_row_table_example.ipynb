# %% [markdown]
# # Distinct Row Table
#
# - The Distinct Row Table (DRT) class gives a the connectivity of the Shavitt graph.
# - We calculate all possible (a,b,c) head nodes for the given number of spatial orbtials

# %%
from pyguga.graph import DistinctRowTable
n_spat_orbs = 10

DistinctRowTable(n_spat_orbs).df
# Out:
#      a  b   c   u  uirrep    k0    k1    k2    k3    l0    l1    l2    l3
# 0    0  0   0   0       1  None  None  None  None     3     2  None     1
# 1    1  0   0   1       2  None  None  None     0     6     5  None     4
# 2    0  1   0   1       3  None     0  None  None     8     7     6     5
# 3    0  0   1   1       4     0  None  None  None     9     8  None     6
# 4    2  0   0   2       5  None  None  None     1    12    11  None    10
# ..  .. ..  ..  ..     ...   ...   ...   ...   ...   ...   ...   ...   ...
# 281  0  4   6  10       6   215   216  None  None  None  None  None  None
# 282  0  3   7  10       1   216   217  None  None  None  None  None  None
# 283  0  2   8  10       2   217   218  None  None  None  None  None  None
# 284  0  1   9  10       3   218   219  None  None  None  None  None  None
# 285  0  0  10  10       1   219  None  None  None  None  None  None  None
#
# [286 rows x 13 columns]
